# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Best Time to Buy and Sell Stock

# %% [markdown]
# You are given an array prices where prices[i] is the price of a given stock on the ith day.
#
# You want to maximize your profit by choosing a single day to buy one stock and choosing a different day in the future to sell that stock.
#
# Return the maximum profit you can achieve from this transaction. If you cannot achieve any profit, return 0.
#
#
#
# Example 1:
#
# Input: prices = [7,1,5,3,6,4]
# Output: 5
# Explanation: Buy on day 2 (price = 1) and sell on day 5 (price = 6), profit = 6-1 = 5.
# Note that buying on day 2 and selling on day 1 is not allowed because you must buy before you sell.
# Example 2:
#
# Input: prices = [7,6,4,3,1]
# Output: 0
# Explanation: In this case, no transactions are done and the max profit = 0.

# %%
def maxProfit(prices):
	fluc = []
	if len(prices) <= 1:
		return 0
	for i in range(len(prices)):
		for j in range(i+1, len(prices)):
			fluc.append(prices[j] - prices[i])
	return max(max(fluc),0)

# Time complexity of this one is n^2 and it is very slow for big arrays
# So this is not optimal solution

# %%
# optimal solution >> two pointers
def maxProfit(prices):
    L = 0
    R = 1
    max_profit = 0
    for _ in range(len(prices)-1):
        profit = prices[R] - prices[L]
        if profit <= 0:
            L = R
            R += 1
        if profit > 0 :
            R += 1
            max_profit = max(profit, max_profit)
    return max_profit

# Time complexity of this one is O(n)

# %%
prices = [7,1,5,3,6,4]
maxProfit(prices)
# Out:
# 5

# %% [markdown]
# # 2. Maximum Subarray

# %% [markdown]
# Given an integer array nums, find the subarray with the largest sum, and return its sum.
#
#
# Example 1:
#
# Input: nums = [-2,1,-3,4,-1,2,1,-5,4]
# Output: 6
# Explanation: The subarray [4,-1,2,1] has the largest sum 6.
# Example 2:
#
# Input: nums = [1]
# Output: 1
# Explanation: The subarray [1] has the largest sum 1.
# Example 3:
#
# Input: nums = [5,4,-1,7,8]
# Output: 23
# Explanation: The subarray [5,4,-1,7,8] has the largest sum 23.

# %%
nums = [-2,1,-3,4,-1,2,1,-5,4]
max_sum = max(nums)
for i in range(len(nums)+1):
    for j in range(i+1, len(nums)+1):
        subsum= np.sum(nums[i: j])
        max_sum = max(max_sum, subsum)
print(max_sum)

# The time complexity of this method is O(n^2)

# %%
# optimal solution with sliding window
def maxSubArray(nums):  
    maxsum = nums[0]
    L = 0
    R = 1
    for i in range(len(nums)):
        subsum = sum(nums[L:R])
        if  subsum  <= 0:
            L = R
            R += 1
            if maxsum < 0:
                maxsum = max(maxsum, subsum)
        if subsum > 0:
            R += 1
            maxsum = max(maxsum, subsum)
    return maxsum

# Time complexity of this solution is O(n2) So this is not the most efficient
# becasue sum[i:j] is O(n) and since it is in a for loop, it is going to be O(n^2)

# %%
nums = [-2, -1]
maxSubArray(nums)
# Out:
# -1

# %%
nums = [-2, -1]

def maxSubArray(nums):  
    L = 0
    R = 1
    max_sum = nums[0]
    current_sum = 0

    for i in range(len(nums)):
        current_sum = current_sum + nums[i]
        if current_sum <= 0 :
            L = R
            R +=1
            max_sum = max(max_sum, current_sum)
            current_sum = 0
        if current_sum > 0 :
            R += 1
            max_sum = max(max_sum, current_sum)
    return max_sum

# Time omplexity of this one is O(n) because we removed the sum[i:j] and we made it
# a simple adding by introducing current sum

# %% [markdown]
# # 3. Move Zeroes

# %% [markdown]
# Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements.
#
# Note that you must do this in-place without making a copy of the array.
#
#
#
# Example 1:
#
# Input: nums = [0,1,0,3,12]
# Output: [1,3,12,0,0]
# Example 2:
#
# Input: nums = [0]
# Output: [0]

# %%
nums = [0]

for i in range(len(nums)-1):
    for i in range(len(nums)-1):
        if nums[i] == 0 and nums[i+1] != 0:
            nums[i] = nums[i+1]
            nums[i+1] = 0

# The time complexity of this is O(n^2) so this is not the optimal solution

# %%
nums = [0,1,0,3,12]

def moveZeros(nums):
    L = 0
    R = 1

    while R < len(nums):
        if nums[L] == 0 and nums[R] != 0:
            nums[L] = nums[R]
            nums[R] = 0
            L +=1
        if nums[L] !=   0:
            L += 1
        R += 1
    return nums   

# The complixity of this one is O(n)

# %%
nums
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# # 4. Merge Sorted Array

# %% [markdown]
# You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n, representing the number of elements in nums1 and nums2 respectively.
#
# Merge nums1 and nums2 into a single array sorted in non-decreasing order.
#
# The final sorted array should not be returned by the function, but instead be stored inside the array nums1. To accommodate this, nums1 has a length of m + n, where the first m elements denote the elements that should be merged, and the last n elements are set to 0 and should be ignored. nums2 has a length of n.
#
#
#
# Example 1:
#
# Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
# Output: [1,2,2,3,5,6]
# Explanation: The arrays we are merging are [1,2,3] and [2,5,6].
# The result of the merge is [1,2,2,3,5,6] with the underlined elements coming from nums1.
# Example 2:
#
# Input: nums1 = [1], m = 1, nums2 = [], n = 0
# Output: [1]
# Explanation: The arrays we are merging are [1] and [].
# The result of the merge is [1].
# Example 3:
#
# Input: nums1 = [0], m = 0, nums2 = [1], n = 1
# Output: [1]
# Explanation: The arrays we are merging are [] and [1].
# The result of the merge is [1].
# Note that because m = 0, there are no elements in nums1. The 0 is only there to ensure the merge result can fit in nums1.

# %%
nums1 = [1,2,3,0,0,0]
m = 3
nums2 = [2,5,6]
n = 3

# %%
nums1[n:] = nums2
sorted(nums1)

# This is good but we are using python function and it has a time complexity of nlogn
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
# This was very difficult to write, so I wtached youtube
# The point is to try to fill nums1 from right, instead of checking from the left

def Merge(nums1, m, nums2, n):
    p1 = m - 1
    p2 = n - 1

    if m == 0 :
        nums1[:] = nums2
    else:    
        while (p1>=0 and p2>=0) :
            # print(p1, p2, nums1[p1], nums2[p2])
            if nums2[p2] > nums1[p1]:
                nums1[p1+p2+1] = nums2[p2]
                p2 = p2 - 1
                # print(nums1[p1])
            else:
                nums1[p1+p2+1] = nums1[p1]
                p1 = p1 - 1
                # print(nums1[p1]) 
        while p2 >= 0:
            nums1[p1+p2+1] = nums2[p2]
            p2 = p2 - 1

    return nums1

# %%
Merge(nums1 = [1], m = 1, nums2=[], n=0)
Merge(nums1 = [2,4,5,0,0,0], m = 3, nums2=[1,2,3], n=3)
# Out:
# [1, 2, 2, 3, 4, 5]

# %%
nums1 = [2,2,2,0]
m = 3
nums2=[2]
n=1

p1 = m - 1
p2 = n - 1

while p1 >= 0 and p2 >=0: 
    # print("p1:", p1)
    # print("p2:", p2)
    # print("max1:", nums1[p1])
    # print("max2:", nums2[p2])
    # print(nums1)
    # print(nums2)
    # print("========")
    if nums2[p2] >= nums1[p1]:
        nums1[p1+p2+1] = nums2[p2]
        p2 = p2 - 1
    else: 
        nums1[p1+p2+1] = nums1[p1]
        nums1[p1] = 0
        p1 = p1 - 1

if p1 < 0 and p2 >=0:
   nums1[:p2+1] = nums2[:p2+1]

nums1
# Out:
# p1: 2
# p2: 0
# max1: 2
# max2: 2
# [2, 2, 2, 0]
# [2]
# ...
# [2, 2, 2, 2]

# %% [markdown]
# # 5. Valid Palindrome

# %% [markdown]
# A phrase is a palindrome if, after converting all uppercase letters into lowercase letters and removing all non-alphanumeric characters, it reads the same forward and backward. Alphanumeric characters include letters and numbers.
#
# Given a string s, return true if it is a palindrome, or false otherwise.
#
#
#
# Example 1:
#
# Input: s = "A man, a plan, a canal: Panama"
# Output: true
# Explanation: "amanaplanacanalpanama" is a palindrome.
# Example 2:
#
# Input: s = "race a car"
# Output: false
# Explanation: "raceacar" is not a palindrome.
# Example 3:
#
# Input: s = " "
# Output: true
# Explanation: s is an empty string "" after removing non-alphanumeric characters.
# Since an empty string reads the same forward and backward, it is a palindrome.

# %%
def valid_palindrom(s):
    ord_numbers = [ord(str(i)) for i in range(10)]
    ord_letters = [i for i in range(ord("a"), ord("z") + 1)]
    accepted_ords = set(ord_numbers + ord_letters)

    L = 0
    R = len(s) - 1

    for i in range(len(s)):
        if L >= R:
            break
        
        if ord(s[L].lower()) not in accepted_ords:
            L = L + 1
            continue
        
        if ord(s[R].lower()) not in accepted_ords:
            R = R - 1
            continue
        
        if s[L].lower() != s[R].lower():
            return False 
        
        L = L + 1
        R = R - 1
                
    return True

# %%
mystr = "A man, a plan, a canal: Panama"
# mystr = "A1"
mystr = "race a car"
valid_palindrom(mystr)
# Out:
# False

# %% [markdown]
# # 6. Product of Array Except Self

# %% [markdown]
# Given an integer array nums, return an array answer such that answer[i] is equal to the product of all the elements of nums except nums[i].
#
# The product of any prefix or suffix of nums is guaranteed to fit in a 32-bit integer.
#
# You must write an algorithm that runs in O(n) time and without using the division operation.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,4]
# Output: [24,12,8,6]
# Example 2:
#
# Input: nums = [-1,1,0,-3,3]
# Output: [0,0,9,0,0]

# %%
nums = [1,2,34,]
# nums = [-1,1,0,-3,3]

result = []
for i, n in enumerate(nums):
    current_prod = 1
    for j, m in enumerate(nums):
        if i == j:
            current_prod  = current_prod  * 1
        else:
            current_prod  = current_prod  * m
    result.append(current_prod)

print(result)

    # But the time complexity of this is O(n^2)
# Out:
# [24, 12, 8, 6]

# %%
# The optimal solution

prefix = [1]
postfix = [1]
current_pre_prod = 1
current_post_prod = 1

for i, _ in enumerate(nums):
    current_pre_prod = current_pre_prod * nums[i]
    prefix.append(current_pre_prod)

for i, _ in enumerate(nums):
    current_post_prod = current_post_prod * nums[len(nums) - 1 - i]
    postfix.append(current_post_prod)
    # print(current_post_prod)

result = []
for i in range(len(nums) + 1):
   if i == 0:
       continue
   else:
      result.append(prefix[i-1]* postfix[len(nums)-i])

# %%
result
# Out:
# [24, 12, 8, 6]
