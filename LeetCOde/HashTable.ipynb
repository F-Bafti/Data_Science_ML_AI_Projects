# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. TwoSum
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]

# %%
def two_sum(arr, target):
    result = ()
    for i in range(len(nums) - 1):
        for j in range(i+1, len(nums)):
            if arr[i] + arr[j] == target:
                result = (i,j)
    return result  

# Time complexity O(n^2)

# %%
nums = [2, 1, 5, 3]
target = 4
two_sum(nums, 4)
# Out:
# (1, 3)

# %%
def two_sum(my_array, target):
    prev_map = {} #val: index
    for i, num in enumerate(my_array):
        x = target - num
        if x in prev_map:
            return (prev_map[x], i)
        else:
            prev_map[num] = i
    return

# Time complexity O(n)

# %%
# Now lets do with hashtable
nums = [2,7,11,15]
target = 9

two_sum(nums, target)
# Out:
# (0, 1)

# %% [markdown]
# # 2. ContainsDuplicate
# Given an integer array nums, return true if any value appears at least twice in the array, and return false if every element is distinct.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3,1]
#
# Output: true
#
# Explanation:
#
# The element 1 occurs at the indices 0 and 3.
#
# Example 2:
#
# Input: nums = [1,2,3,4]
#
# Output: false
#
# Explanation:
#
# All elements are distinct.
#
# Example 3:
#
# Input: nums = [1,1,1,3,3,4,3,2,4,2]
#
# Output: true

# %%
nums = [-1,2,3,1]

result = False

for i in range(len(nums)):
    for j in range(i + 1, len(nums)):
        if nums[i] == nums[j]:
            result = True
            exit
print(result)

# The brute force time complexitiy is O(n^2)
# Out:
# False

# %%
def containsDuplicate(nums):
    hash_table = {}
    result = False
    for i, n in enumerate(nums):
        if n in hash_table:
            result = True
            return result
        else:
            hash_table[n] = i
    return result

# Time complexity O(n)

# %%
containsDuplicate([1, 2, 3, 4, 5, 5])
# Out:
# True

# %%
containsDuplicate([1, 2, 3, 4, -5, 5])
# Out:
# False

# %% [markdown]
# # 3. Valid Anagram
#
# Given two strings s and t, return true if t is an anagram of s, and false otherwise.
#
#
#
# Example 1:
#
# Input: s = "anagram", t = "nagaram"
#
# Output: true
#
# Example 2:
#
# Input: s = "rat", t = "car"
#
# Output: false

# %%
def IsAnagaram(s, t):

    def count_strings(string):
        count_s = {}
        for s in string:
            if s in count_s:
                count_s[s] += 1
            else:
                count_s[s] = 1    
        return count_s
    
    return count_strings(s) == count_strings(t)

# %%
s = "anagram"
t = "nagaram"

IsAnagaram(s, t)
# Out:
# True

# %% [markdown]
# # 4. Group Anagrams
# Given an array of strings strs, group the anagrams together. You can return the answer in any order.
#
# Example 1:
#
# Input: strs = ["eat","tea","tan","ate","nat","bat"]
#
# Output: [["bat"],["nat","tan"],["ate","eat","tea"]]
#
# Explanation:
#
# There is no string in strs that can be rearranged to form "bat".
# The strings "nat" and "tan" are anagrams as they can be rearranged to form each other.
# The strings "ate", "eat", and "tea" are anagrams as they can be rearranged to form each other.
# Example 2:
#
# Input: strs = [""]
#
# Output: [[""]]
#
# Example 3:
#
# Input: strs = ["a"]
#
# Output: [["a"]]

# %%
strs = ["eat","tea","tan","ate","nat","bat"]

def groupAnagrams(strs):
    grs = {}
    for str in strs:
        sortstr = "".join(sorted(str)) # This is an important step
        if  sortstr in grs:
            grs[sortstr].append(str)
        else:
            grs[sortstr] = [str]

    return  [v for k,v in grs.items()]

# Time complexity is m * n log n 
# nlogn is the time complexity of sorting
# m is the length of each string

# %%
groupAnagrams(strs)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]

# %%
# Optimal solution
strs = ["eat","tea","tan","ate","nat","bat"]

def groupanagrams(strs):
    def count_str(mystr):
        count_s = [0] * 26 # letters
        for ch in mystr:
            count_s[ord(ch) - ord("a")] += 1
        return tuple(count_s)

    table = {}
    for str in strs:
        s_count = count_str(str)
        if s_count in table:
            table[s_count].append(str)
        else:
            table[s_count] = [str]

    return  [v for k, v in table.items()]

# Time comlexity is O(m * n) where m is the length of str list and n is the evrage of the lenght of each character

# %% [markdown]
# # 5. Intersection of Two Arrays
# Given two integer arrays nums1 and nums2, return an array of their intersection. Each element in the result must be unique and you may return the result in any order.
#
# Example 1:
#
# Input: nums1 = [1,2,2,1], nums2 = [2,2]
# Output: [2]
# Example 2:
#
# Input: nums1 = [4,9,5], nums2 = [9,4,9,8,4]
# Output: [9,4]
# Explanation: [4,9] is also accepted.

# %%
num1 = [4, 9, 5]
num2 = [9, 4, 9, 8, 4]

def intersection(num1, num2):
    table = set(num1)
    result = []
    for n in  num2:
        if n in table:
            result.append(n)

    return [i for i in set(result)]

# %% [markdown]
# # 6. Intersection of Two Arrays II
#
# Given two integer arrays nums1 and nums2, return an array of their intersection. Each element in the result must appear as many times as it shows in both arrays and you may return the result in any order.
#
# Example 1:
#
# Input: nums1 = [1,2,2,1], nums2 = [2,2]
# Output: [2,2]
# Example 2:
#
# Input: nums1 = [4,9,5], nums2 = [9,4,9,8,4]
# Output: [4,9]
# Explanation: [9,4] is also accepted.

# %%
def count_n(nums):
    result = {}
    for n in nums:
        if n in result:
            result[n] += 1
        else:
            result[n] = 1
    return result

# %%
def intersect(nums1, nums2):
        def count_n(nums):
            result = {}
            for n in nums:
                if n in result:
                    result[n] += 1
                else:
                    result[n] = 1
            return result

        table1 = count_n(nums1)
        table2 = count_n(nums2)
        occur = []
        for k1, v1 in table1.items():
            if k1 in table2:
                freq = min(v1, table2[k1])
                for f in range(freq):
                    occur.append(k1)   
        return occur

# %%
nums1 = [4,9,5,9]
nums2 = [9,4,9,8,4]

intersect(nums1, nums2)
# Out:
# [4, 9, 9]

# %% [markdown]
# # 7. First Unique Character in a String
# Given a string s, find the first non-repeating character in it and return its index. If it does not exist, return -1.
#
# Example 1:
#
# Input: s = "leetcode"
#
# Output: 0
#
# Explanation:
#
# The character 'l' at index 0 is the first character that does not occur at any other index.
#
# Example 2:
#
# Input: s = "loveleetcode"
#
# Output: 2
#
# Example 3:
#
# Input: s = "aabb"
#
# Output: -1

# %%
def firstUniqChar(mystr):
    def count_str(mystr):
        count_s = {}
        for i, s in enumerate(mystr):
            if s in count_s:
                count_s[s].append(i)
            else:
                count_s[s] = [i]
        return count_s

    table = count_str(mystr)
    for i, s in enumerate(mystr):
        if len(table[s]) == 1:
            result = i
            break
        else:
            result = -1

    return result

# %%
firstUniqChar("leetcode")
# Out:
# 0

# %%
firstUniqChar("loveleetcode")
# Out:
# 2

# %%
firstUniqChar("aabb")
# Out:
# -1

# %%
len(table[s])
# Out:
# 1

# %% [markdown]
# # 8. Happy Number
# Write an algorithm to determine if a number n is happy.
#
# A happy number is a number defined by the following process:
#
# Starting with any positive integer, replace the number by the sum of the squares of its digits.
# Repeat the process until the number equals 1 (where it will stay), or it loops endlessly in a cycle which does not include 1.
# Those numbers for which this process ends in 1 are happy.
# Return true if n is a happy number, and false if not.
#
# Example 1:
#
# Input: n = 19
# Output: true
# Explanation:
# 1 + 81 = 82
# 64 + 4 = 68
# 36 + 64 = 100
# 1 + 0 + 0 = 1
#
# Example 2:
# Input: n = 2
# Output: false

# %%
def isHappy(num):
    def get_sum_sq(num):
        sum_sq = 0
        for s in str(num):
            sum_sq += int(s)**2
        return sum_sq

    tab = set()

    while True:
        ss = get_sum_sq(num)    
        if ss == 1:
            return True
        elif ss in tab:
            return False
        else:
            tab.add(ss)
        num = ss

# %%
isHappy(19)
# Out:
# True

# %% [markdown]
# # 9. Isomorphic Strings
# Given two strings s and t, determine if they are isomorphic.
#
# Two strings s and t are isomorphic if the characters in s can be replaced to get t.
#
# All occurrences of a character must be replaced with another character while preserving the order of characters. No two characters may map to the same character, but a character may map to itself.
#
# Example 1:
#
# Input: s = "egg", t = "add"
#
# Output: true
#
# Explanation:
#
# The strings s and t can be made identical by:
#
# Mapping 'e' to 'a'.
# Mapping 'g' to 'd'.
# Example 2:
#
# Input: s = "foo", t = "bar"
#
# Output: false
#
# Explanation:
#
# The strings s and t can not be made identical as 'o' needs to be mapped to both 'a' and 'r'.
#
# Example 3:
#
# Input: s = "paper", t = "title"
#
# Output: true

# %%
def ind_count_str(mystr):
    ind_count_s = {}
    for i, s in enumerate(mystr):
        if s in ind_count_s:
            ind_count_s[s][0] += 1
            ind_count_s[s].append(i)
        else:
            ind_count_s[s] = [1, i]
    return ind_count_s

# %%
mystr = "title"
s_1 = ind_count_str(mystr)

mystr = "paper"
s_2 = ind_count_str(mystr)

# [v for k,v in s_1.items()] == [v for k,v in s_2.items()]

# %%
tuple(tuple(v) for k,v in s_1.items()) == tuple(tuple(v) for k,v in s_2.items())
# Out:
# True

# %%
def isIsomorphic(s, t):
    def ind_count_str(mystr):
        ind_count_s = {}
        for i, s in enumerate(mystr):
            if s in ind_count_s:
                ind_count_s[s][0] += 1
                ind_count_s[s].append(i)
            else:
                ind_count_s[s] = [1, i]
        return ind_count_s
    
    s_count = ind_count_str(s)
    t_count = ind_count_str(t)

    return set([tuple(v) for _,v in s_count.items()]) == set([tuple(v) for _,v in t_count.items()])

# %%
isIsomorphic("fifth", "gigan")
# Out:
# True

# %% [markdown]
# #  10. Ransom Note
#
# Given two strings ransomNote and magazine, return true if ransomNote can be constructed by using the letters from magazine and false otherwise.
#
# Each letter in magazine can only be used once in ransomNote.
#
# Example 1:
#
# Input: ransomNote = "a", magazine = "b"
# Output: false
# Example 2:
#
# Input: ransomNote = "aa", magazine = "ab"
# Output: false
# Example 3:
#
# Input: ransomNote = "aa", magazine = "aab"
# Output: true

# %%
def canConstruct(ransomNote, magazine):
    def count_s(mystr):
        count_s = {}
        for s in mystr:
            if s in count_s:
                count_s[s] +=1
            else:
                count_s[s] = 1
        return count_s

    magazin_count = count_s(magazine)
    result = True
    for s in ransomNote:
        if s in magazin_count and magazin_count[s] > 0:
            magazin_count[s] -= 1
        else:
            result = False

    return result

# %%
ransomNote = "aa"
magazine = "ab"

canConstruct(ransomNote, magazin_count)
# Out:
# False

# %% [markdown]
# # Word Pattern
#
# Given a pattern and a string s, find if s follows the same pattern.
#
# Here follow means a full match, such that there is a bijection between a letter in pattern and a non-empty word in s. Specifically:
#
# Each letter in pattern maps to exactly one unique word in s.
# Each unique word in s maps to exactly one letter in pattern.
# No two letters map to the same word, and no two words map to the same letter.
#
#
# Example 1:
#
# Input: pattern = "abba", s = "dog cat cat dog"
#
# Output: true
#
# Explanation:
#
# The bijection can be established as:
#
# 'a' maps to "dog".
# 'b' maps to "cat".
# Example 2:
#
# Input: pattern = "abba", s = "dog cat cat fish"
#
# Output: false
#
# Example 3:
#
# Input: pattern = "aaaa", s = "dog cat cat dog"
#
# Output: false

# %%
def wordPattern(pattern, s):

    s = s.split(" ")
    pattern = [p for p in pattern]
    result = True
    t = {}
    
    if (len(s) != len(pattern)):
        return False
    
    if (len(set(s)) != len(set(pattern))):
            return False
            
    for i, p in enumerate(pattern):
        if p in t:
            if t[p] != s[i]:
                return False
        else:
            t[p] = s[i]

    return result

# %%
pattern = "aaa"
s = "dog dog dog dog"
wordPattern(pattern, s)
# Out:
# False

# %% [markdown]
# # Top K Frequent Elements

# %%
nums = [1,2,1,2,1,2,3,1,3,2]
k = 2

def topKFreq(nums, k):
    table = {}
    # Count the freq of each element
    for i, n in enumerate(nums):
        if n in table:
            table[n] += 1
        else:
            table[n] = 1

    # bucket sort them based on their freq in a list of lists
    freq = [[] for i in range(len(nums) + 1)]
    for e, v in table.items():
        freq[v].append(e)

    res = []
    for i in range(len(freq) - 1, 0, -1):
        for n in freq[i]:
            res.append(n)
            if len(res) == k:
                return res

# %%
topKFreq(nums,k)
# Out:
# [1, 2]

# %% [markdown]
# # Top K Frequent Words

# %%
words = ["the","day","is","sunny","the","the","the","sunny","is","is"]
k = 4

count = {}
freq_order = [[] for i in range(len(words)+1)]
res = []

for i, w in enumerate(words):
    if w in count:
        count[w] += 1
    else:
        count[w] = 1

for w, freq in count.items():
    freq_order[freq].append(w)

for i in range(len(freq_order) - 1, 0, -1):
    for m in sorted(freq_order[i]):  # Here is very important to put the sorted becasue otherwise the list of list
        # will have a list of all strings but the strings in each lists is not sorted. so if all the strings have the
        # same frequency, then the returned list is not sorted 
        res.append(m)
        if len(res) == k:
            break

# %% [markdown]
# # Majority Element

# %%
nums = [2,2,1,1,1,2,2]

target = len(nums) // 2
count = {}

for i, n in enumerate(nums):
    if n in count:
        count[n] += 1
    else:
        count[n] = 1

    if count[n] > target :
            print(n)
            break
# Out:
# 2

# %% [markdown]
# # Subarray Sum Equals K

# %%
nums = [1,2,3]
k = 3
sublists = []

for i in range(len(nums)):
    l_sum = 0
    for j in range(i, len(nums)):
        l_sum = sum(nums[i: j+1])
        if l_sum == k:
            sublists.append(nums[i: j+1])

# %%
sublists
# Out:
# [[1, 2], [3]]

# %%
nums = [1,1,1]
k=3

L = 0
R = 0
tsum = 0
sublists = []

while (L < len(nums) and R < len(nums)):
    tsum = tsum + nums[R]
    print(L, R,  tsum)

    if tsum < k:
        R = R + 1

    elif tsum == k:
        sublists.append(nums[L:R+1])
        tsum = tsum - nums[L]
        L = L + 1

    else:  # tsum > k
        tsum = tsum - nums[L]
        L = L + 1
# Out:
# 0 0 1
# 0 1 2
# 0 2 3
# 1 2 3
# 2 2 3

# %%
860/7
# Out:
# 122.85714285714286

# %% [markdown]
# # Longest Consecutive Sequence

# %% [markdown]
# # You can continue solving these:
# 	•
# 	•	Subarray Sum Equals K
# 	•	Longest Consecutive Sequence
# 	•	Continuous Subarray Sum
# 	•	Jewels and Stones
# 	•	Find the Difference
# 	•	Set Mismatch
# 	•	Four Sum II
# 	•	Design HashMap
# 	•	Design HashSet
